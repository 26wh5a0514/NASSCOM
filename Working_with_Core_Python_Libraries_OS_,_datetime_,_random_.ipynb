# %% [markdown]
# <a href="https://colab.research.google.com/github/26wh5a0514/NASSCOM/blob/python_code/Working_with_Core_Python_Libraries_OS_%2C_datetime_%2C_random_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Working with Core Python Libraries
#
# We will explore:
#
# 📁 os – interacting with the operating system
#
# 📆 datetime – working with dates and times
#
# 🎲 random – generating random numbers and choices
#
# 📦 collections – specialized container datatypes

# %% [markdown]
# #📁 1. os – Operating System Interface

# %%
import os

# Get current working directory
print("Current Directory:", os.getcwd())

# List files and directories in current directory
print("Files and Folders:", os.listdir())

# Create a new folder
os.mkdir("demo_folder")  # Creates folder named 'demo_folder'

# Rename a folder

os.rename("demo_folder", "renamed_folder")

# Remove a folder (make sure it's empty)
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %% [markdown]
# #📆 2. datetime – Date and Time Handling

# %%
from datetime import datetime, date, timedelta

# Current date and time
now = datetime.now()
print("Now:", now)

# Only today's date
today = date.today()
print("Today's Date:", today)

# Create a specific date
dob = date(2000, 1, 1)
print("DOB:", dob)

# Date arithmetic
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)

print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)

# Format date to string
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-09-17 15:36:57.458959
# Today's Date: 2026-09-17
# DOB: 2000-01-01
# Yesterday: 2026-09-16
# Tomorrow: 2026-09-18
# Formatted DateTime: 17-09-2026 15:36:57

# %% [markdown]
# #🎲 3. random – Random Numbers & Choices

# %%
import random

# Generate random integer between 1 and 100
num=list(range(1,99))
random.shuffle(num)
c=0
for i in num:
  if(c<3):
    print(i,end = " ")
    c+=1
  else:
    c=0
    print("")
# Out:
# 97 67 47
# 32 37 95
# 86 66 56
# 54 98 22
# 68 27 50
# 90 38 18
# 3 25 78
# 94 75 1
# 6 40 84
# 59 43 89
# 29 7 14
# 63 23 33
# 57 5 65
# 4 44 55
# 71 41 35
# 83 17 92
# 13 48 70
# 21 85 62
# 26 64 91
# 42 45 8
# 20 36 58
# 52 87 60
# 46 10 82
# 31 72 69
# 73 51

# %%
x=list(map(int,input().split()))
print(x)
# Out:
# 1 2 3
# [1, 2, 3]

# %% [markdown]
# #📦 4. collections – Specialized Containers
# 🔹 A. Counter

# %%
from collections import Counter

# Count occurrences of elements in a list
fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %% [markdown]
# 🔹 B. defaultdict

# %%
from collections import defaultdict

# Returns a default value for missing keys
marks = defaultdict(lambda: 0)
marks['Math'] = 90
marks['Science'] = 80
print("English Marks (not set):", marks['English'])  # Returns 0
# Out:
# English Marks (not set): 0

# %% [markdown]
# 🔹 C. namedtuple

# %%
from collections import namedtuple

# Create a Point object with x and y
Point = namedtuple('Point', 'x y')
p1 = Point(10, 20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %% [markdown]
# 🔹 D. deque

# %%
from collections import deque

# Double-ended queue
dq = deque([1, 2, 3])
dq.append(4)        # Add to right
dq.appendleft(0)    # Add to left
dq.pop()            # Remove from right
dq.popleft()        # Remove from left
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])

# %% [markdown]
# #✅ Summary Table
#
# | Library       | Purpose                                  | Example Function               |
# | ------------- | ---------------------------------------- | ------------------------------ |
# | `os`          | File/directory operations                | `os.mkdir()`, `os.listdir()`   |
# | `datetime`    | Date and time manipulation               | `datetime.now()`, `timedelta`  |
# | `random`      | Random generation                        | `random.choice()`, `shuffle()` |
# | `collections` | Advanced containers (`Counter`, `deque`) | `Counter()`, `defaultdict()`   |
