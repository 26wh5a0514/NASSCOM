# %% [markdown]
# <a href="https://colab.research.google.com/github/26wh5a0514/NASSCOM/blob/main/Python_CoreExerciseDay1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")

# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
raw_sensor_data = []

for i in range(1, 101):
    time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    id = "DEV" + str(i).zfill(3)
    type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value = READING_RANGES[type][0]
    max_value = READING_RANGES[type][1]

    value = round(random.uniform(min_value, max_value), 2)

    raw_sensor_data.append((time, id, type, location, value))

print(raw_sensor_data)






# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature_Sensor'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.

# Your code for Task 1.2 here:
temperature_readings = []

for data in raw_sensor_data:
    if data[2] == "Temperature_Sensor":
        reading = {
            "timestamp": data[0],
            "device_id": data[1],
            "location": data[3],
            "temperature_celsius": data[4]
        }

        temperature_readings.append(reading)

print(temperature_readings)




# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.

# Your code for Task 1.3 here:
unique_locations = set()

for data in raw_sensor_data:
    unique_locations.add(data[3])

print(unique_locations)



# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.

# Your code for Task 1.4 here:
device_stats = {}

for data in raw_sensor_data:
    device_type = data[2]
    value = data[4]

    if device_type not in device_stats:
        device_stats[device_type] = (value, value)
    else:
        min_value = device_stats[device_type][0]
        max_value = device_stats[device_type][1]

        if value < min_value:
            min_value = value

        if value > max_value:
            max_value = value

        device_stats[device_type] = (min_value, max_value)

print(device_stats)




# 1.5: Advanced Indexing and Slicing (Lists and Strings)
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")

# Let's use 'raw_sensor_data' and create a sample string for these tasks.
sample_string = "PythonProgrammingIsFun"

# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.

# Your code for Task 1.5.1 here:
sliced_readings_1 = raw_sensor_data[9:20]
sliced_readings_2 = raw_sensor_data[::5]
print("Sliced readings 1:")
print(sliced_readings_1)
print("Sliced readings 2:")
print(sliced_readings_2)



# 1.5.2 String Slicing: Extract the substring "Programming" from 'sample_string'.
#       Store the result in 'substring_1'.
#       Then, extract the substring "nohtyP" (the reverse of "Python") from 'sample_string' using slicing.
#       Store the result in 'substring_2'.

# Your code for Task 1.5.2 here:
sample_string = "PythonProgrammingIsFun"
substring_1 = sample_string[6:17]
substring_2 = sample_string[5::-1]
print("Substring 1:", substring_1)
print("Substring 2:", substring_2)



# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.

# Your code for Task 1.5.3 here:

fifth_reading_device_type = raw_sensor_data[4][2]
device_type_suffix = fifth_reading_device_type[-6:]

print("Fifth reading device type:", fifth_reading_device_type)
print("Device type suffix:", device_type_suffix)




# --- Task 2: Writing and Using Functions in Python ---
print("\n--- Task 2: Function Definitions and Usage ---")

# 2.1 Write a function `get_readings_by_location(readings_list, target_location)`
#     that takes the 'raw_sensor_data' list and a 'target_location' string.
#     It should return a list of all readings (as tuples) for that specific location.

# Your code for Task 2.1 here:
def get_readings_by_location(readings_list, target_location):
    result = []
    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)
    return result
location = input("Enter location: ")
readings = get_readings_by_location(raw_sensor_data, location)
print("Readings at", location, ":")
print(readings)


# 2.2 Write a function `calculate_average_temperature(temp_data_list)`
#     that takes the 'temperature_readings' list (list of dictionaries).
#     It should calculate and return the average temperature. Return 0.0 if the list is empty.

# Your code for Task 2.2 here:
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for data in temp_data_list:
        total = total + data["temperature_celsius"]

    average = total / len(temp_data_list)

    return average


average_temperature = calculate_average_temperature(temperature_readings)

print("Average Temperature:", average_temperature)



# 2.3 Write a function `generate_report_line(reading_dict)`
#     that takes a single temperature reading dictionary.
#     It should return a formatted string like:
#     "[{timestamp}] Device {device_id} at {location}: {temperature_celsius}°C"

# Your code for Task 2.3 here:
def generate_report_line(reading_dict):
    return "[{}] Device {} at {}: {}°C".format(
        reading_dict["timestamp"],
        reading_dict["device_id"],
        reading_dict["location"],
        reading_dict["temperature_celsius"]
    )
if len(temperature_readings) > 0:
    print(generate_report_line(temperature_readings[0]))



# --- Task 3: Working with Core Python Libraries (os, datetime, random) ---
print("\n--- Task 3: Core Library Usage ---")

# 3.1 Use the `os` module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.

# Your code for Task 3.1 here:
if not os.path.exists("sensor_reports"):
    os.mkdir("sensor_reports")

print("Directory created successfully")



# 3.2 Calculate the duration between the first and last timestamp in 'raw_sensor_data'.
#     Convert string timestamps to datetime objects first.
#     Print the duration in days, hours, and minutes.

# Your code for Task 3.2 here:
first_time = datetime.datetime.strptime(
    raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S"
)

last_time = datetime.datetime.strptime(
    raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S"
)

duration = last_time - first_time

print("Duration:", duration)


# 3.3 Generate a list of 5 random integer values between 100 and 200 (inclusive)
#     using the `random` module. Store it in 'random_values'.

# Your code for Task 3.3 here:
random_values = []

for i in range(5):
    value = random.randint(100, 200)
    random_values.append(value)

print("Random values:", random_values)



# --- Task 4: File Handling in Python ---
print("\n--- Task 4: File I/O ---")

# 4.1 Write all 'temperature_readings' to a file named 'sensor_reports/temperature_report.txt'.
#     Each line in the file should be generated using the `generate_report_line` function.

# Your code for Task 4.1 here:
file = open("sensor_reports/temperature_report.txt", "w")

for reading in temperature_readings:
    line = generate_report_line(reading)
    file.write(line + "\n")

file.close()

print("Temperature report created")


# 4.2 Read the content of 'sensor_reports/temperature_report.txt' back into a list of strings
#     named 'read_report_lines'. Print the first 3 lines.

# Your code for Task 4.2 here:
file = open("sensor_reports/temperature_report.txt", "r")

read_report_lines = file.readlines()

file.close()

print("First 3 lines:")

for line in read_report_lines[:3]:
    print(line.strip())





print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# [('2026
026-08-14 16:13:42', 'DEV038', 'Temperature_Sensor', 'Lab2', 18.63), ('2026-08-14 16:13:42', 'DEV039', 'Temperature_Sensor', 'Lab1', 26.44), ('2026-08-14 16:13:42', 'DEV040', 'Light_Sensor', 'Lab2', 333.17), ('2026-08-14 16:13:42', 'DEV041', 'Pressure_Sensor', 'OfficeA', 990.92), ('2026-08-14 16:13:42', 'DEV042', 'Humidity_Sensor', 'Lab2', 62.83), ('2026-08-14 16:13:42', 'DEV043', 'Pressure_Sensor', 'OfficeB', 993.38), ('2026-08-14 16:13:42', 'DEV044', 'Temperature_Sensor', 'Lab2', 25.52), ('2026-08-14 16:13:42', 'DEV045', 'Light_Sensor', 'OfficeB', 766.15), ('2026-08-14 16:13:42', 'DEV046', 'Light_Sensor', 'OfficeB', 471.81), ('2026-08-14 16:13:42', 'DEV047', 'Temperature_Sensor', 'Warehouse', 29.98), ('2026-08-14 16:13:42', 'DEV048', 'Humidity_Sensor', 'Lab2', 63.85), ('2026-08-14 16:13:42', 'DEV049', 'Temperature_Sensor', 'Lab1', 25.59), ('2026-08-14 16:13:42', 'DEV050', 'Humidity_Sensor', 'OfficeA', 34.23), ('2026-08-14 16:13:42', 'DEV051', 'Temperature_Sensor', 'OfficeA', 24.82), ('2026-08-14 16:13:42', 'DEV052', 'Temperature_Sensor', 'Lab2', 21.52), ('2026-08-14 16:13:42', 'DEV053', 'Temperature_Sensor', 'OfficeB', 25.05), ('2026-08-14 16:13:42', 'DEV054', 'Humidity_Sensor', 'OfficeA', 32.58), ('2026-08-14 16:13:42', 'DEV055', 'Light_Sensor', 'Lab2', 830.69), ('2026-08-14 16:13:42', 'DEV056', 'Humidity_Sensor', 'Warehouse', ...
# [{'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV005', 'location': 'Warehouse', 'temperature_celsius': 19.09}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV008', 'location': 'OfficeB', 'temperature_celsius': 21.55}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV010', 'location': 'Lab2', 'temperature_celsius': 19.57}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV012', 'location': 'Warehouse', 'temperature_celsius': 18.4}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV016', 'location': 'Lab1', 'temperature_celsius': 20.18}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV019', 'location': 'Warehouse', 'temperature_celsius': 22.11}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV021', 'location': 'OfficeB', 'temperature_celsius': 28.93}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV024', 'location': 'Lab2', 'temperature_celsius': 29.18}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV029', 'location': 'OfficeB', 'temperature_celsius': 18.17}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV033', 'location': 'Lab1', 'temperature_celsius': 22.85}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV035', 'location': 'Warehouse', 'temperature_celsius': 19.35}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV038', 'location': 'Lab2', 'temperature_celsius': 18.63}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV039', 'location': 'Lab1', 'temperature_celsius': 26.44}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV044', 'location': 'Lab2', 'temperature_celsius': 25.52}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV047', 'location': 'Warehouse', 'temperature_celsius': 29.98}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV049', 'location': 'Lab1', 'temperature_celsius': 25.59}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV051', 'location': 'OfficeA', 'temperature_celsius': 24.82}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV052', 'location': 'Lab2', 'temperature_celsius': 21.52}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV053', 'location': 'OfficeB', 'temperature_celsius': 25.05}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV058', 'location': 'Lab1', 'temperature_celsius': 29.98}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV069', 'location': 'Lab2', 'temperature_celsius': 24.19}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV072', 'location': 'Warehouse', 'temperature_celsius': 28.1}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV074', 'location': 'OfficeA', 'temperature_celsius': 25.07}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV076', 'location': 'Lab1', 'temperature_celsius': 28.96}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV078', 'location': 'OfficeA', 'temperature_celsius': 18.55}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV079', 'location': 'Warehouse', 'temperature_celsius': 18.5}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV083', 'location': 'Warehouse', 'temperature_celsius': 28.99}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV085', 'location': 'Lab1', 'temperature_celsius': 18.82}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV092', 'location': 'Lab1', 'temperature_celsius': 20.5}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV097', 'location': 'Warehouse', 'temperature_celsius': 24.12}, {'timestamp': '2026-08-14 16:13:42', 'device_id': 'DEV099', 'location': 'Lab2', 'temperature_celsius': 25.87}]
# {'Warehouse', 'OfficeB', 'OfficeA', 'Lab2', 'Lab1'}
# {'Pressure_Sensor': (982.9, 1029.39), 'Humidity_Sensor': (31.82, 78.69), 'Light_Sensor': (299.34, 964.27), 'Temperature_Sensor': (18.17, 29.98)}
#
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
# Sliced readings 1:
# [('2026-08-14 16:13:42', 'DEV010', 'Temperature_Sensor', 'Lab2', 19.57), ('2026-08-14 16:13:42', 'DEV011', 'Pressure_Sensor', 'OfficeA', 986.06), ('2026-08-14 16:13:42', 'DEV012', 'Temperature_Sensor', 'Warehouse', 18.4), ('2026-08-14 16:13:42', 'DEV013', 'Light_Sensor', 'Lab2', 838.71), ('2026-08-14 16:13:42', 'DEV014', 'Light_Sensor', 'OfficeB', 427.03), ('2026-08-14 16:13:42', 'DEV015', 'Light_Sensor', 'Lab1', 693.6), ('2026-08-14 16:13:42', 'DEV016', 'Temperature_Sensor', 'Lab1', 20.18), ('2026-08-14 16:13:42', 'DEV017', 'Light_Sensor', 'Lab1', 381.58), ('2026-08-14 16:13:42', 'DEV018', 'Humidity_Sensor', 'Lab1', 77.25), ('2026-08-14 16:13:42', 'DEV019', 'Temperature_Sensor', 'Warehouse', 22.11), ('2026-08-14 16:13:42', 'DEV020', 'Light_Sensor', 'Lab1', 496.22)]
# Sliced readings 2:
# [('2026-08-14 16:13:42', 'DEV001', 'Pressure_Sensor', 'Lab2', 982.9), ('2026-08-14 16:13:42', 'DEV006', 'Pressure_Sensor', 'Warehouse', 1013.17), ('2026-08-14 16:13:42', 'DEV011', 'Pressure_Sensor', 'OfficeA', 986.06), ('2026-08-14 16:13:42', 'DEV016', 'Temperature_Sensor', 'Lab1', 20.18), ('2026-08-14 16:13:42', 'DEV021', 'Temperature_Sensor', 'OfficeB', 28.93), ('2026-08-14 16:13:42', 'DEV026', 'Light_Sensor', 'OfficeA', 749.72), ('2026-08-14 16:13:42', 'DEV031', 'Humidity_Sensor', 'OfficeB', 41.58), ('2026-08-14 16:13:42', 'DEV036', 'Humidity_Sensor', 'OfficeA', 53.68), ('2026-08-14 16:13:42', 'DEV041', 'Pressure_Sensor', 'OfficeA', 990.92), ('2026-08-14 16:13:42', 'DEV046', 'Light_Sensor', 'OfficeB', 471.81), ('2026-08-14 16:13:42', 'DEV051', 'Temperature_Sensor', 'OfficeA', 24.82), ('2026-08-14 16:13:42', 'DEV056', 'Humidity_Sensor', 'Warehouse', 39.65), ('2026-08-14 16:13:42', 'DEV061', 'Light_Sensor', 'OfficeB', 720.19), ('2026-08-14 16:13:42', 'DEV066', 'Humidity_Sensor', 'OfficeB', 70.25), ('2026-08-14 16:13:42', 'DEV071', 'Pressure_Sensor', 'Lab1', 1014.03), ('2026-08-14 16:13:42', 'DEV076', 'Temperature_Sensor', 'Lab1', 28.96), ('2026-08-14 16:13:42', 'DEV081', 'Humidity_Sensor', 'OfficeA', 61.16), ('2026-08-14 16:13:42', 'DEV086', 'Pressure_Sensor', 'Lab1', 1026.45), ('2026-08-14 16:13:42', 'DEV091', 'Pressure_Sensor', 'OfficeA', 984.25), ('2026-08-14 16:13:42', 'DEV096', 'Pressure_Sensor', 'Lab1', 1024.25)]
# Substring 1: Programming
# Substring 2: nohtyP
# Fifth reading device type: Temperature_Sensor
# Device type suffix: Sensor
#
# --- Task 2: Function Definitions and Usage ---
# Enter location: Lab1
# Readings at Lab1 :
# [('2026-08-14 16:13:42', 'DEV002', 'Humidity_Sensor', 'Lab1', 66.85), ('2026-08-14 16:13:42', 'DEV003', 'Light_Sensor', 'Lab1', 507.4), ('2026-08-14 16:13:42', 'DEV015', 'Light_Sensor', 'Lab1', 693.6), ('2026-08-14 16:13:42', 'DEV016', 'Temperature_Sensor', 'Lab1', 20.18), ('2026-08-14 16:13:42', 'DEV017', 'Light_Sensor', 'Lab1', 381.58), ('2026-08-14 16:13:42', 'DEV018', 'Humidity_Sensor', 'Lab1', 77.25), ('2026-08-14 16:13:42', 'DEV020', 'Light_Sensor', 'Lab1', 496.22), ('2026-08-14 16:13:42', 'DEV033', 'Temperature_Sensor', 'Lab1', 22.85), ('2026-08-14 16:13:42', 'DEV039', 'Temperature_Sensor', 'Lab1', 26.44), ('2026-08-14 16:13:42', 'DEV049', 'Temperature_Sensor', 'Lab1', 25.59), ('2026-08-14 16:13:42', 'DEV058', 'Temperature_Sensor', 'Lab1', 29.98), ('2026-08-14 16:13:42', 'DEV063', 'Humidity_Sensor', 'Lab1', 68.83), ('2026-08-14 16:13:42', 'DEV070', 'Humidity_Sensor', 'Lab1', 64.7), ('2026-08-14 16:13:42', 'DEV071', 'Pressure_Sensor', 'Lab1', 1014.03), ('2026-08-14 16:13:42', 'DEV073', 'Pressure_Sensor', 'Lab1', 985.0), ('2026-08-14 16:13:42', 'DEV076', 'Temperature_Sensor', 'Lab1', 28.96), ('2026-08-14 16:13:42', 'DEV080', 'Humidity_Sensor', 'Lab1', 78.69), ('2026-08-14 16:13:42', 'DEV085', 'Temperature_Sensor', 'Lab1', 18.82), ('2026-08-14 16:13:42', 'DEV086', 'Pressure_Sensor', 'Lab1', 1026.45), ('2026-08-14 16:13:42', 'DEV089', 'Humidity_Sensor', 'Lab1', 64.27), ('2026-08-14 16:13:42', 'DEV092', 'Temperature_Sensor', 'Lab1', 20.5), ('2026-08-14 16:13:42', 'DEV093', 'Humidity_Sensor', 'Lab1', 64.4), ('2026-08-14 16:13:42', 'DEV096', 'Pressure_Sensor', 'Lab1', 1024.25), ('2026-08-14 16:13:42', 'DEV100', 'Humidity_Sensor', 'Lab1', 45.39)]
# Average Temperature: 23.50258064516129
# [2026-08-14 16:13:42] Device DEV005 at Warehouse: 19.09°C
#
# --- Task 3: Core Library Usage ---
# Directory created successfully
# Duration: 0:00:00
# Random values: [107, 172, 115, 101, 165]
#
# --- Task 4: File I/O ---
# Temperature report created
# First 3 lines:
# [2026-08-14 16:13:42] Device DEV005 at Warehouse: 19.09°C
# [2026-08-14 16:13:42] Device DEV008 at OfficeB: 21.55°C
# [2026-08-14 16:13:42] Device DEV010 at Lab2: 19.57°C
#
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
